# %% [markdown]
# # 🚀 Finetune Compiler - Colab T4 Launcher
#
# Launch the Wizard UI on Colab's Tesla T4 GPU.
#
# **Run cells in order!**

# %%
# 1️⃣ Check GPU
# !nvidia-smi --query-gpu=name --format=csv,noheader

# %%
# 2️⃣ Clone & Install
import os

if not os.path.exists('/content/Finetune-Compiler'):
    # !git clone https://github.com/khedhar108/Finetune-Compiler.git /content/Finetune-Compiler
else:
    # !cd /content/Finetune-Compiler && git pull

os.chdir('/content/Finetune-Compiler')
print(f"📂 Now in: {os.getcwd()}")

# !pip install uv -q
# !uv sync --extra ui --extra unsloth

# %%
# 3️⃣ Verify
# !uv run ai-compile info

# %%
# 4️⃣ Launch UI
#
# ⚠️ IMPORTANT NOTES:
# -----------------------------------------------------------------
# 1. USE THE PUBLIC URL (gradio.live) - Local URL won't work from your PC
#
# 2. DON'T STOP THIS CELL - Stopping kills the UI server!
#    The cell MUST keep running for the UI to stay accessible.
#
# 3. LINK EXPIRES IN 1 WEEK - Just re-run this cell to get a new one
#
# 4. TRAINING RUNS IN BACKGROUND - You can train while using the UI,
#    training uses the T4 GPU even though the UI is running here.
#
# 5. COLAB SESSION TIMEOUT - Colab may disconnect after ~90 min idle.
#    Keep the tab active or use Colab Pro for longer sessions.
# -----------------------------------------------------------------

# !uv run ai-compile ui2 --share
